# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharanivaradharajan/bharani/blob/main/Ner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import and load the spacy model
import spacy
nlp=spacy.load("en_core_web_sm")

# Getting the ner component
ner=nlp.get_pipe('ner')

# %%
LABEL = "ORTHO"

# Training data for orthopedic nanoresearch papers with annotated entities including categorized properties
TRAIN_DATA = [
    ("Recent advancements in nanotechnology have revolutionized orthopedic surgery.", {"entities": []}),
    ("Nanostructured scaffolds have shown promise in enhancing bone regeneration processes.", {"entities": [(0, 17, "TECHNOLOGY"), (40, 50, "PROCEDURE")]}),
    ("Silver nanoparticles have demonstrated antimicrobial properties, making them suitable for orthopedic implant coatings.", {"entities": [(0, 20, "MATERIAL"), (42, 52, "CHEMICAL_PROPERTY"), (62, 72, "APPLICATION")]}),
    ("A novel drug delivery system utilizing nanocarriers has been proposed for targeted therapy in orthopedic diseases.", {"entities": [(17, 38, "TECHNOLOGY"), (61, 71, "APPLICATION"), (75, 93, "DISEASE")]}),
    ("Graphene-based nanomaterials have exhibited remarkable mechanical properties for orthopedic applications.", {"entities": [(0, 20, "MATERIAL"), (54, 64, "MECHANICAL_PROPERTY"), (68, 81, "APPLICATION")]}),
    ("Nanoparticle-based imaging techniques offer high-resolution visualization of orthopedic implants.", {"entities": [(0, 12, "MATERIAL"), (36, 57, "TECHNIQUE"), (61, 78, "APPLICATION")]}),
    ("Recent studies have investigated the biocompatibility of nanomaterials for orthopedic tissue engineering.", {"entities": [(32, 45, "PHYSICAL_PROPERTY"), (49, 61, "MATERIAL"), (65, 90, "APPLICATION")]}),
    ("Polymeric nanocomposites have been explored for developing lightweight orthopedic implants.", {"entities": [(0, 22, "MATERIAL"), (61, 72, "APPLICATION")]}),
    ("Nanotechnology-enabled drug delivery systems show potential for targeted treatment of orthopedic infections.", {"entities": [(0, 14, "TECHNOLOGY"), (32, 53, "APPLICATION"), (75, 86, "DISEASE")]}),
    ("Functionalized nanoparticles have been proposed for improving the osseointegration of orthopedic implants.", {"entities": [(0, 23, "MATERIAL"), (63, 77, "APPLICATION")]}),
    ("The use of nanofibers in orthopedic scaffolds offers enhanced mechanical strength and cell adhesion properties.", {"entities": [(12, 22, "MATERIAL"), (26, 43, "APPLICATION"), (49, 71, "MECHANICAL_PROPERTY")]}),
    ("Carbon nanotubes have emerged as promising candidates for reinforcing orthopedic composite materials.", {"entities": [(0, 18, "MATERIAL"), (70, 81, "APPLICATION")]}),
    ("Nanoparticle-based gene therapy holds potential for treating genetic orthopedic disorders.", {"entities": [(0, 12, "MATERIAL"), (30, 40, "APPLICATION"), (64, 83, "DISEASE")]}),
    ("Incorporating nanoceramics into orthopedic coatings enhances their wear resistance and biocompatibility.", {"entities": [(14, 26, "MATERIAL"), (30, 49, "APPLICATION"), (53, 68, "PHYSICAL_PROPERTY")]}),
    ("Gold nanoparticles have been investigated for their potential in photothermal therapy for orthopedic cancers.", {"entities": [(0, 18, "MATERIAL"), (63, 80, "APPLICATION"), (84, 94, "DISEASE")]}),
    ("Nanotechnology-based bone substitutes offer improved integration and reduced rejection rates in orthopedic surgeries.", {"entities": [(0, 15, "TECHNOLOGY"), (31, 47, "APPLICATION"), (52, 68, "PHYSICAL_PROPERTY"), (72, 87, "PROCEDURE")]}),
    ("The application of nanorobots in orthopedic medicine shows promise for targeted drug delivery and tissue repair.", {"entities": [(21, 31, "TECHNOLOGY"), (35, 57, "APPLICATION"), (61, 74, "APPLICATION")]}),
    ("Magnetic nanoparticles have been utilized for guided tissue engineering in orthopedics.", {"entities": [(0, 20, "MATERIAL"), (44, 64, "APPLICATION")]}),
    ("Implantable nanosensors provide real-time monitoring of orthopedic implant performance and patient health.", {"entities": [(13, 26, "TECHNOLOGY"), (51, 78, "APPLICATION")]}),
    ("Nanoparticle-based coatings have been developed to improve the biocompatibility of orthopedic devices.", {"entities": [(0, 12, "MATERIAL"), (47, 67, "PHYSICAL_PROPERTY"), (71, 89, "APPLICATION")]}),
    ("Carbon nanomaterials offer lightweight and durable alternatives for orthopedic prosthetics.", {"entities": [(0, 18, "MATERIAL"), (57, 68, "APPLICATION"), (73, 84, "PRODUCT")]}),
    ("Nanoparticle-mediated gene editing holds potential for correcting hereditary orthopedic conditions.", {"entities": [(0, 12, "MATERIAL"), (33, 45, "APPLICATION"), (69, 88, "DISEASE")]}),
    ("Bone composition consists mainly of minerals like calcium and phosphate, providing strength and rigidity.",
     {"entities": [(0, 16, "Bone Composition"), (41, 48, "Mineral"), (53, 61, "Mineral"), (82, 89, "Property"), (94, 102, "Property")]}),

    ("The morphology of bone tissue varies, with shapes ranging from compact to trabecular.",
     {"entities": [(4, 13, "Morphology"), (29, 33, "Property"), (38, 47, "Property"), (58, 66, "Property")]}),

    ("The chemical composition of bone includes hydroxyapatite, collagen, and various trace elements.",
     {"entities": [(4, 23, "Chemical Composition"), (32, 45, "Mineral"), (47, 54, "Mineral"), (59, 66, "Mineral"), (71, 79, "Property"), (84, 91, "Property"), (96, 113, "Property")]}),

    ("Hydroxyapatite (HA) ceramics are widely used in orthopedic applications due to their biocompatibility and osteoconductivity.",
     {"entities": [(0, 15, "Mineral"), (18, 20, "Mineral"), (23, 30, "Material"), (42, 57, "Property"), (62, 77, "Property")]}),

    ("The structure of bone at the nano level is crucial for understanding its mechanical properties.",
     {"entities": [(4, 12, "Structure"), (29, 38, "Morphology"), (64, 76, "Property")]}),

    ("Calcium and phosphate ions play a significant role in bone mineralization and remodeling processes.",
     {"entities": [(0, 6, "Mineral"), (11, 19, "Mineral"), (53, 67, "Process")]}),

    ("The nanostructure of bone tissue contributes to its remarkable mechanical strength and flexibility.",
     {"entities": [(4, 14, "Structure"), (29, 39, "Morphology"), (60, 76, "Property"), (81, 92, "Property")]}),

    ("The presence of collagen fibers in bone matrix enhances its tensile strength and resilience.",
     {"entities": [(18, 25, "Material"), (29, 42, "Morphology"), (51, 65, "Property"), (70, 79, "Property")]}),

    ("Phosphate ions in bone hydroxyapatite are involved in buffering acidic metabolites and maintaining pH balance.",
     {"entities": [(0, 8, "Mineral"), (12, 28, "Mineral"), (32, 47, "Material"), (53, 82, "Process"), (87, 101, "Process")]}),

    ("The hierarchical structure of bone tissue provides both strength and resilience to withstand mechanical stresses.",
     {"entities": [(4, 21, "Structure"), (29, 42, "Morphology"), (55, 62, "Property"), (67, 77, "Property"), (82, 91, "Property")]}),

    ("Minerals such as magnesium and potassium are also present in bone, contributing to its overall composition.",
     {"entities": [(12, 20, "Mineral"), (25, 34, "Mineral"), (68, 79, "Property"), (84, 97, "Property"), (102, 113, "Property")]}),
    ("The nanoscale architecture of bone tissue, including collagen fibers and mineralized matrix, contributes to its exceptional mechanical properties.",
     {"entities": [(4, 22, "Structure"), (34, 49, "Material"), (54, 72, "Material"), (98, 115, "Property"), (120, 131, "Property"), (136, 150, "Property")]}),

    ("Trace elements like zinc and copper are essential for bone metabolism and play vital roles in bone remodeling processes.",
     {"entities": [(17, 21, "Mineral"), (26, 31, "Mineral"), (65, 78, "Process"), (83, 99, "Process")]}),

    ("The mineral composition of bone is dynamic, with continuous deposition and resorption processes throughout life.",
     {"entities": [(4, 23, "Composition"), (56, 68, "Process"), (73, 83, "Process")]}),

    ("Nanotechnology has enabled the development of novel bone implants with enhanced mechanical strength and bioactivity.",
     {"entities": [(0, 13, "Technology"), (61, 67, "Material"), (78, 96, "Property"), (101, 111, "Property")]}),

    ("Osteocytes, embedded within the bone matrix, play crucial roles in mechanotransduction and bone remodeling.",
     {"entities": [(0, 10, "Cell"), (33, 47, "Material"), (58, 73, "Process"), (78, 93, "Process")]}),

    ("The chemical complexity of bone tissue, comprising various proteins, minerals, and growth factors, influences its regenerative capacity.",
     {"entities": [(4, 22, "Complexity"), (36, 44, "Material"), (46, 54, "Material"), (59, 67, "Material"), (72, 86, "Property"), (95, 116, "Property")]}),

    ("The nanostructure of bone hydroxyapatite crystals contributes to their excellent mechanical properties and biocompatibility.",
     {"entities": [(4, 14, "Structure"), (29, 48, "Material"), (58, 75, "Property"), (80, 97, "Property")]}),

    ("Bone mineral density is a key parameter used to assess bone health and risk of fractures.",
     {"entities": [(0, 21, "Density"), (56, 66, "Parameter"), (72, 80, "Assessment"), (85, 104, "Process")]}),

    ("The osteoblasts' production of osteoid, a collagen-rich matrix, is critical for bone formation and mineralization.",
     {"entities": [(4, 14, "Cell"), (34, 40, "Material"), (43, 57, "Material"), (80, 95, "Process"), (100, 116, "Process")]}),

    ("The unique nanoarchitecture of bone tissue, with its hierarchical organization, underlies its remarkable mechanical properties.",
     {"entities": [(4, 28, "Nanoarchitecture"), (44, 58, "Organization"), (68, 86, "Property"), (91, 101, "Property")]}),

    ("Nanomaterials such as carbon nanotubes and graphene derivatives have shown promise in enhancing bone regeneration and implant integration.",
     {"entities": [(0, 12, "Nanomaterial"), (18, 37, "Material"), (42, 63, "Material"), (90, 107, "Process"), (112, 133, "Process")]}),

    ("The nanostructured surface of bone implants can modulate cellular responses and improve osseointegration.",
     {"entities": [(4, 22, "Surface"), (27, 43, "Implant"), (67, 87, "Response"), (92, 109, "Integration")]}),

    ("Bone extracellular matrix, rich in collagen and glycoproteins, provides a supportive environment for cell adhesion and proliferation.",
     {"entities": [(0, 26, "Matrix"), (42, 49, "Material"), (54, 67, "Material"), (91, 104, "Environment"), (109, 122, "Adhesion"), (127, 140, "Proliferation")]}),

    ("The mechanical behavior of bone is highly anisotropic, exhibiting different properties along various axes.",
     {"entities": [(4, 25, "Behavior"), (29, 40, "Bone"), (45, 57, "Property"), (101, 110, "Axis")]}),

    ("Bone morphogenetic proteins (BMPs) play essential roles in regulating bone development, growth, and repair processes.",
     {"entities": [(0, 30, "Protein"), (54, 67, "Process"), (72, 77, "Process"), (82, 96, "Process")]}),

    ("The nanostructured architecture of bone tissue confers both strength and flexibility, essential for its load-bearing function.",
     {"entities": [(4, 26, "Architecture"), (31, 45, "Bone"), (55, 62, "Property"), (67, 80, "Property"), (105, 119, "Function")]}),

    ("The remodeling of bone tissue involves a balance between osteoblastic bone formation and osteoclastic bone resorption.",
     {"entities": [(4, 13, "Remodeling"), (17, 28, "Bone"), (41, 51, "Balance"), (67, 83, "Formation"), (88, 106, "Resorption")]}),

    ("Nanoparticles coated with bioactive molecules can promote osteogenic differentiation and accelerate bone healing.",
     {"entities": [(0, 13, "Nanoparticles"), (26, 51, "Coating"), (66, 91, "Differentiation"), (96, 112, "Healing")]}),

    ("The nanoscale topography of bone surfaces influences cell behavior and tissue regeneration processes.",
     {"entities": [(4, 19, "Topography"), (23, 45, "Surface"), (55, 63, "Behavior"), (68, 89, "Regeneration"), (99, 107, "Process")]}),
    ("The hierarchical organization of bone tissue, from the nano to the macro level, imparts its unique mechanical properties.",
     {"entities": [(4, 28, "Organization"), (42, 54, "Bone"), (60, 67, "Level"), (84, 90, "Property"), (95, 107, "Property")]}),

    ("Nanoparticles functionalized with growth factors can stimulate bone regeneration and accelerate healing processes.",
     {"entities": [(0, 13, "Nanoparticles"), (29, 45, "Functionalization"), (50, 64, "Factors"), (78, 95, "Regeneration"), (100, 112, "Healing")]}),

    ("The composition and structure of bone extracellular matrix are essential for cell adhesion and signaling pathways.",
     {"entities": [(4, 26, "Composition"), (31, 39, "Structure"), (44, 69, "Matrix"), (89, 102, "Adhesion"), (107, 127, "Signaling")]}),

    ("Nanoparticles loaded with antibiotics can prevent implant-related infections and promote osseointegration.",
     {"entities": [(0, 13, "Nanoparticles"), (21, 35, "Loading"), (41, 51, "Antibiotics"), (68, 88, "Infections"), (93, 111, "Integration")]}),

    ("The spatial distribution of osteocytes within bone tissue regulates bone remodeling activities and maintains homeostasis.",
     {"entities": [(4, 29, "Distribution"), (33, 42, "Cell"), (52, 66, "Bone"), (78, 92, "Remodeling"), (97, 108, "Activities"), (113, 124, "Homeostasis")]}),

    ("Nanoporous scaffolds fabricated from biodegradable polymers offer a supportive environment for bone tissue regeneration.",
     {"entities": [(0, 14, "Nanoporous"), (24, 34, "Scaffolds"), (44, 55, "Fabrication"), (61, 82, "Polymers"), (97, 120, "Environment"), (125, 147, "Regeneration")]}),

    ("The nanoscale architecture of bone apatite crystals governs their mechanical behavior and bioactivity.",
     {"entities": [(4, 22, "Architecture"), (26, 38, "Bone"), (39, 46, "Apatite"), (55, 71, "Behavior"), (76, 86, "Bioactivity")]}),

    ("Bone morphogenetic proteins (BMPs) play pivotal roles in inducing osteogenic differentiation and bone formation.",
     {"entities": [(0, 30, "Proteins"), (34, 38, "BMPs"), (52, 80, "Roles"), (85, 116, "Differentiation"), (121, 136, "Formation")]}),

    ("Nanocomposite materials composed of hydroxyapatite and polymers mimic the natural bone structure and enhance tissue integration.",
     {"entities": [(0, 15, "Nanocomposite"), (25, 42, "Materials"), (52, 67, "Hydroxyapatite"), (72, 81, "Polymers"), (95, 121, "Structure"), (126, 148, "Integration")]}),

    ("The surface roughness of bone implants influences cell adhesion, proliferation, and ultimately, osseointegration.",
     {"entities": [(4, 20, "Surface"), (24, 38, "Implants"), (50, 63, "Adhesion"), (68, 83, "Proliferation"), (88, 105, "Osseointegration")]}),

    ("Bone mineralization begins with the nucleation of calcium phosphate crystals, followed by their growth and alignment.",
     {"entities": [(4, 19, "Mineralization"), (37, 56, "Nucleation"), (60, 78, "Calcium Phosphate"), (86, 91, "Crystals"), (101, 106, "Growth"), (111, 120, "Alignment")]}),

    ("The porous structure of bone tissue facilitates nutrient and waste exchange, essential for cell metabolism and viability.",
     {"entities": [(4, 20, "Structure"), (26, 37, "Bone"), (47, 56, "Nutrient"), (61, 74, "Exchange"), (89, 100, "Metabolism"), (105, 115, "Viability")]}),

    ("Nanoscale modifications of titanium implants can improve their osseointegration and long-term stability in bone tissue.",
     {"entities": [(0, 18, "Modifications"), (22, 39, "Titanium Implants"), (53, 68, "Osseointegration"), (73, 91, "Long-term Stability"), (96, 106, "Bone Tissue")]}),

    ("Bone tissue engineering strategies involve the use of biomaterials and scaffolds to regenerate damaged or diseased bones.",
     {"entities": [(0, 21, "Tissue Engineering"), (33, 46, "Strategies"), (57, 68, "Biomaterials"), (73, 82, "Scaffolds"), (96, 111, "Regeneration"), (116, 136, "Damaged or Diseased Bones")]}),

    ("The porosity and pore size of bone scaffolds affect cell infiltration, vascularization, and tissue ingrowth.",
     {"entities": [(4, 12, "Porosity"), (17, 27, "Pore Size"), (32, 46, "Scaffolds"), (54, 67, "Infiltration"), (72, 86, "Vascularization"), (91, 103, "Tissue Ingrowth")]}),

    ("Biomineralization processes in bone involve the controlled deposition of minerals to form the bone matrix and regulate bone density.",
     {"entities": [(0, 22, "Biomineralization Processes"), (26, 30, "Bone"), (45, 63, "Deposition"), (67, 75, "Minerals"), (93, 104, "Matrix"), (109, 123, "Density")]}),

    ("Osteoclasts, multinucleated cells, play a crucial role in bone resorption by breaking down the bone matrix and releasing minerals.",
     {"entities": [(0, 11, "Osteoclasts"), (13, 33, "Multinucleated Cells"), (57, 71, "Resorption"), (76, 91, "Bone Matrix"), (96, 105, "Minerals")]}),

    ("The integration of biomaterials with native bone tissue depends on factors such as material composition, surface properties, and implant design.",
     {"entities": [(4, 15, "Integration"), (19, 31, "Biomaterials"), (36, 51, "Native Bone Tissue"), (67, 84, "Material Composition"), (89, 105, "Surface Properties"), (110, 122, "Implant Design")]}),

    ("Bone regeneration involves a complex interplay of cells, growth factors, and extracellular matrix components to restore bone structure and function.",
     {"entities": [(0, 17, "Regeneration"), (38, 43, "Cells"), (45, 58, "Growth Factors"), (63, 94, "Extracellular Matrix Components"), (99, 116, "Bone Structure"), (121, 130, "Function")]}),

    ("The surface chemistry of biomaterials influences protein adsorption, cell adhesion, and subsequent tissue response.",
     {"entities": [(4, 20, "Surface Chemistry"), (24, 36, "Biomaterials"), (49, 67, "Protein Adsorption"), (72, 83, "Cell Adhesion"), (88, 108, "Tissue Response")]}),

    ("Osteogenic differentiation of mesenchymal stem cells is induced by biochemical and mechanical cues present in the bone microenvironment.",
     {"entities": [(0, 24, "Osteogenic Differentiation"), (28, 57, "Mesenchymal Stem Cells"), (77, 89, "Biochemical Cues"), (94, 113, "Mechanical Cues"), (122, 140, "Bone Microenvironment")]}),

    ("The mechanical properties of bone, including stiffness and toughness, are determined by its hierarchical structure and mineral composition.",
     {"entities": [(4, 22, "Mechanical Properties"), (28, 35, "Bone"), (44, 52, "Stiffness"), (57, 66, "Toughness"), (85, 104, "Structure"), (109, 126, "Mineral Composition")]}),

    ("Osteoprogenitor cells, precursor cells to osteoblasts, play a vital role in bone repair and regeneration processes.",
     {"entities": [(0, 20, "Osteoprogenitor Cells"), (49, 59, "Precursor Cells"), (64, 74, "Osteoblasts"), (85, 91, "Repair"), (96, 116, "Regeneration Processes")]}),

    ("The architecture of cancellous bone provides a balance between structural support and efficient nutrient diffusion.",
     {"entities": [(4, 16, "Architecture"), (27, 42, "Cancellous Bone"), (51, 58, "Balance"), (71, 88, "Structural Support"), (93, 118, "Nutrient Diffusion")]}),

    ("Biomimetic scaffolds mimic the structure and properties of natural bone to promote cell adhesion and tissue regeneration.",
     {"entities": [(0, 16, "Biomimetic Scaffolds"), (38, 45, "Structure"), (50, 59, "Properties"), (67, 78, "Natural Bone"), (83, 96, "Cell Adhesion"), (101, 121, "Tissue Regeneration")]}),

    ("The nanoarchitecture of bone extracellular matrix governs cell behavior and differentiation processes during bone formation.",
     {"entities": [(4, 18, "Nanoarchitecture"), (22, 45, "Bone Extracellular Matrix"), (53, 67, "Behavior"), (72, 92, "Differentiation Processes"), (102, 116, "Bone Formation")]}),

    ("Bone tissue response to mechanical loading involves mechanotransduction pathways that regulate bone remodeling and adaptation.",
     {"entities": [(0, 12, "Bone Tissue"), (23, 40, "Mechanical Loading"), (46, 64, "Mechanotransduction Pathways"), (73, 89, "Remodeling"), (94, 106, "Adaptation")]}),

    ("The architecture of trabecular bone contributes to its high strength-to-weight ratio and resilience under load-bearing conditions.",
     {"entities": [(4, 16, "Architecture"), (27, 42, "Trabecular Bone"), (53, 68, "Strength-to-weight Ratio"), (73, 83, "Resilience"), (88, 105, "Load-bearing Conditions")]}),

    ("Biomaterial implants coated with bioactive molecules enhance osseointegration and reduce the risk of implant failure.",
     {"entities": [(0, 18, "Biomaterial Implants"), (28, 35, "Coated"), (40, 57, "Bioactive Molecules"), (67, 83, "Osseointegration"), (88, 106, "Implant Failure")]}),

    ("Bone remodeling is regulated by a balance between osteoblastic bone formation and osteoclastic bone resorption processes.",
     {"entities": [(0, 15, "Bone Remodeling"), (25, 43, "Balance"), (58, 74, "Osteoblastic Bone Formation"), (79, 99, "Osteoclastic Bone Resorption Processes")]}),

    ("Nanotechnology-based strategies for bone repair involve the delivery of growth factors and cells to enhance tissue regeneration.",
     {"entities": [(0, 14, "Nanotechnology-based Strategies"), (31, 41, "Bone Repair"), (67, 79, "Delivery"), (84, 96, "Growth Factors"), (101, 106, "Cells"), (121, 142, "Tissue Regeneration")]}),

    ("Bone tissue is continuously remodeled through a process involving bone formation by osteoblasts and bone resorption by osteoclasts.",
     {"entities": [(0, 11, "Bone Tissue"), (25, 34, "Remodeled"), (56, 71, "Bone Formation by Osteoblasts"), (76, 98, "Bone Resorption by Osteoclasts")]}),

    ("The nanostructured surface of titanium implants promotes cell adhesion and osseointegration for improved implant stability.",
     {"entities": [(4, 22, "Nanostructured Surface"), (28, 45, "Titanium Implants"), (55, 68, "Cell Adhesion"), (73, 89, "Osseointegration"), (94, 119, "Improved Implant Stability")]}),

    ("Osteocytes, embedded within the bone matrix, are involved in mechanosensing and signaling pathways that regulate bone remodeling.",
     {"entities": [(0, 10, "Osteocytes"), (24, 39, "Bone Matrix"), (57, 69, "Mechanosensing"), (74, 89, "Signaling Pathways"), (98, 114, "Bone Remodeling")]}),

    ("Nanomaterials offer unique properties such as high surface area and tunable mechanical strength, making them ideal for bone tissue engineering.",
     {"entities": [(0, 13, "Nanomaterials"), (26, 34, "Properties"), (39, 54, "Surface Area"), (59, 85, "Tunable Mechanical Strength"), (91, 116, "Ideal for Bone Tissue Engineering")]}),

    ("The composition and microstructure of bone influence its mechanical properties and biological responses to external stimuli.",
     {"entities": [(4, 16, "Composition"), (21, 33, "Microstructure"), (38, 43, "Bone"), (53, 71, "Mechanical Properties"), (76, 94, "Biological Responses"), (98, 115, "External Stimuli")]}),

    ("The hierarchical organization of collagen fibers in bone provides strength and resilience to withstand mechanical loads.",
     {"entities": [(4, 28, "Hierarchical Organization"), (32, 47, "Collagen Fibers"), (51, 55, "Bone"), (64, 71, "Strength"), (76, 86, "Resilience"), (90, 107, "Mechanical Loads")]}),

    ("Bone tissue engineering utilizes biomimetic scaffolds and growth factors to promote cell proliferation and tissue regeneration.",
     {"entities": [(0, 21, "Bone Tissue Engineering"), (32, 48, "Biomimetic Scaffolds"), (53, 65, "Growth Factors"), (79, 96, "Cell Proliferation"), (101, 121, "Tissue Regeneration")]}),

    ("The mineralization of bone involves the deposition of calcium phosphate crystals, which contribute to bone hardness and strength.",
     {"entities": [(4, 17, "Mineralization"), (27, 51, "Deposition"), (55, 72, "Calcium Phosphate Crystals"), (78, 88, "Bone Hardness"), (93, 100, "Strength")]}),

    ("Osteoinductive biomaterials promote the differentiation of mesenchymal stem cells into osteoblasts, leading to bone formation.",
     {"entities": [(0, 24, "Osteoinductive Biomaterials"), (32, 43, "Differentiation"), (48, 67, "Mesenchymal Stem Cells"), (71, 81, "Osteoblasts"), (90, 102, "Bone Formation")]}),

    ("Bone tissue remodeling is orchestrated by a balance between matrix deposition by osteoblasts and matrix resorption by osteoclasts.",
     {"entities": [(0, 17, "Bone Tissue Remodeling"), (38, 48, "Balance"), (67, 86, "Matrix Deposition by Osteoblasts"), (91, 111, "Matrix Resorption by Osteoclasts")]}),

    ("The nanostructure of bone mineral crystals contributes to its mechanical properties, such as hardness and elasticity.",
     {"entities": [(4, 22, "Nanostructure"), (26, 39, "Bone Mineral Crystals"), (51, 70, "Mechanical Properties"), (76, 84, "Hardness"), (89, 99, "Elasticity")]}),

    ("Osteocytes play a critical role in bone mechanotransduction, converting mechanical stimuli into biochemical signals for bone remodeling.",
     {"entities": [(0, 10, "Osteocytes"), (29, 46, "Bone Mechanotransduction"), (67, 86, "Mechanical Stimuli"), (91, 108, "Biochemical Signals"), (113, 128, "Bone Remodeling")]}),

    ("Biomaterials with controlled porosity and surface chemistry can modulate cell behavior and tissue regeneration in bone defects.",
     {"entities": [(0, 12, "Biomaterials"), (17, 35, "Controlled Porosity"), (40, 57, "Surface Chemistry"), (72, 83, "Cell Behavior"), (88, 108, "Tissue Regeneration"), (112, 123, "Bone Defects")]}),

    ("The nanoscale features of bone extracellular matrix regulate cell adhesion and differentiation during bone formation and remodeling.",
     {"entities": [(4, 18, "Nanoscale Features"), (22, 45, "Bone Extracellular Matrix"), (54, 67, "Cell Adhesion"), (72, 88, "Differentiation"), (97, 112, "Bone Formation"), (117, 128, "Remodeling")]}),

    ("Biomimetic coatings on orthopedic implants can enhance osseointegration and reduce the risk of implant-related complications.",
     {"entities": [(0, 12, "Biomimetic Coatings"), (16, 32, "Orthopedic Implants"), (36, 53, "Osseointegration"), (58, 88, "Risk Reduction"), (93, 127, "Implant-related Complications")]}),

    ("The mechanical properties of bone tissue are influenced by factors such as collagen orientation, mineral content, and microarchitecture.",
     {"entities": [(4, 22, "Mechanical Properties"), (28, 42, "Bone Tissue"), (47, 60, "Influenced by Factors"), (65, 83, "Collagen Orientation"), (88, 102, "Mineral Content"), (107, 122, "Microarchitecture")]}),

    ("Biomimetic nanofibrous scaffolds provide a biomimetic microenvironment for cell attachment and proliferation in bone tissue engineering.",
     {"entities": [(0, 12, "Biomimetic"), (13, 29, "Nanofibrous Scaffolds"), (49, 63, "Biomimetic Microenvironment"), (68, 82, "Cell Attachment"), (87, 101, "Proliferation"), (106, 127, "Bone Tissue Engineering")]}),

    ("The structural hierarchy of bone tissue, from the nano to the macro level, determines its mechanical strength and resilience.",
     {"entities": [(4, 24, "Structural Hierarchy"), (28, 42, "Bone Tissue"), (48, 60, "Level"), (76, 94, "Mechanical Strength"), (99, 109, "Resilience")]}),

    ("Biomaterial surface modifications with bioactive molecules can promote osteogenic differentiation and accelerate bone healing.",
     {"entities": [(0, 18, "Biomaterial Surface Modifications"), (24, 41, "Bioactive Molecules"), (63, 86, "Osteogenic Differentiation"), (91, 107, "Bone Healing")]}),

    ("The nanoscale topography of bone surfaces influences cell behavior and tissue regeneration processes.",
     {"entities": [(4, 20, "Nanoscale Topography"), (24, 38, "Bone Surfaces"), (48, 60, "Cell Behavior"), (65, 86, "Tissue Regeneration Processes")]}),
    ("Hydroxyapatite-coated implants enhance osseointegration by promoting osteoblast adhesion and bone formation.",
     {"entities": [(0, 14, "Hydroxyapatite-coated Implants"), (31, 47, "Osseointegration"), (51, 72, "Osteoblast Adhesion"), (77, 90, "Bone Formation")]}),

    ("Nanoparticles functionalized with growth factors have been shown to stimulate osteogenic differentiation and bone regeneration.",
     {"entities": [(0, 13, "Nanoparticles"), (29, 45, "Functionalization"), (50, 64, "Growth Factors"), (85, 112, "Osteogenic Differentiation"), (117, 133, "Bone Regeneration")]}),

    ("The nanoarchitecture of bone extracellular matrix is crucial for guiding cell behavior and promoting tissue regeneration.",
     {"entities": [(4, 18, "Nanoarchitecture"), (22, 45, "Bone Extracellular Matrix"), (58, 70, "Cell Behavior"), (75, 97, "Tissue Regeneration")]}),

    ("Biomaterial scaffolds with controlled porosity and surface chemistry are designed to mimic the natural bone microenvironment.",
     {"entities": [(0, 16, "Biomaterial Scaffolds"), (30, 48, "Controlled Porosity"), (53, 70, "Surface Chemistry"), (99, 122, "Natural Bone Microenvironment")]}),

    ("Nanofibrous scaffolds provide a biomimetic environment that supports cell adhesion and proliferation for bone tissue engineering.",
     {"entities": [(0, 16, "Nanofibrous Scaffolds"), (36, 51, "Biomimetic Environment"), (62, 75, "Cell Adhesion"), (80, 94, "Proliferation"), (99, 121, "Bone Tissue Engineering")]}),

    ("The mineralization process in bone involves the deposition of hydroxyapatite crystals, contributing to bone strength and hardness.",
     {"entities": [(4, 20, "Mineralization Process"), (28, 51, "Deposition"), (55, 70, "Hydroxyapatite Crystals"), (84, 90, "Bone Strength"), (95, 104, "Hardness")]}),

    ("Bone remodeling is a dynamic process that maintains bone homeostasis by balancing osteoblastic bone formation and osteoclastic bone resorption.",
     {"entities": [(0, 15, "Bone Remodeling"), (43, 58, "Bone Homeostasis"), (62, 80, "Osteoblastic Bone Formation"), (85, 113, "Osteoclastic Bone Resorption")]}),

    ("Nanotechnology offers novel approaches for bone repair, including the development of nanocomposite materials and targeted drug delivery systems.",
     {"entities": [(0, 13, "Nanotechnology"), (44, 56, "Bone Repair"), (81, 103, "Nanocomposite Materials"), (108, 137, "Targeted Drug Delivery Systems")]}),

    ("The mechanical properties of bone are influenced by factors such as bone density, microarchitecture, and collagen orientation.",
     {"entities": [(4, 22, "Mechanical Properties"), (28, 32, "Bone"), (52, 65, "Bone Density"), (67, 82, "Microarchitecture"), (87, 106, "Collagen Orientation")]}),

    ("Osteocytes play a critical role in bone metabolism, sensing mechanical strain and orchestrating bone remodeling activities.",
     {"entities": [(0, 10, "Osteocytes"), (34, 49, "Bone Metabolism"), (58, 77, "Mechanical Strain"), (82, 114, "Bone Remodeling Activities")]}),

    ("The hierarchical organization of bone tissue is essential for its load-bearing capacity and resistance to fractures.",
     {"entities": [(4, 28, "Hierarchical Organization"), (32, 45, "Bone Tissue"), (57, 74, "Load-bearing Capacity"), (79, 99, "Resistance to Fractures")]}),

    ("Biomimetic coatings on orthopedic implants mimic the extracellular matrix of bone, promoting cell attachment and tissue integration.",
     {"entities": [(0, 18, "Biomimetic Coatings"), (22, 38, "Orthopedic Implants"), (58, 80, "Extracellular Matrix of Bone"), (90, 106, "Cell Attachment"), (111, 130, "Tissue Integration")]}),

    ("Bone tissue regeneration requires a suitable scaffold that provides structural support and bioactive cues for cell proliferation.",
     {"entities": [(0, 14, "Bone Tissue Regeneration"), (47, 55, "Suitable Scaffold"), (60, 78, "Structural Support"), (83, 94, "Bioactive Cues"), (99, 116, "Cell Proliferation")]}),

    ("The extracellular matrix of bone serves as a reservoir for growth factors and signaling molecules involved in bone development and repair.",
     {"entities": [(4, 25, "Extracellular Matrix of Bone"), (36, 46, "Reservoir"), (51, 64, "Growth Factors"), (69, 89, "Signaling Molecules"), (97, 117, "Bone Development and Repair")]}),

    ("Nanoparticle-based drug delivery systems offer targeted and controlled release of therapeutic agents for bone regeneration and disease treatment.",
     {"entities": [(0, 33, "Nanoparticle-based Drug Delivery Systems"), (39, 46, "Targeted"), (51, 71, "Controlled Release"), (76, 96, "Therapeutic Agents"), (101, 120, "Bone Regeneration and Disease Treatment")]}),

    ("The nanostructure of bone tissue provides a large surface area for cell attachment and interaction, facilitating tissue repair and regeneration.",
     {"entities": [(4, 18, "Nanostructure"), (22, 34, "Bone Tissue"), (44, 59, "Large Surface Area"), (64, 81, "Cell Attachment and Interaction"), (98, 116, "Tissue Repair and Regeneration")]}),

    ("Biomaterial scaffolds with biodegradable properties degrade over time, allowing for gradual tissue ingrowth and integration.",
     {"entities": [(0, 16, "Biomaterial Scaffolds"), (22, 39, "Biodegradable Properties"), (49, 59, "Degrade over Time"), (84, 102, "Gradual Tissue Ingrowth"), (107, 118, "Integration")]}),

    ("Osteogenic differentiation of stem cells is regulated by biochemical signals and mechanical cues present in the bone microenvironment.",
     {"entities": [(0, 24, "Osteogenic Differentiation"), (28, 38, "Stem Cells"), (52, 69, "Biochemical Signals"), (74, 91, "Mechanical Cues"), (100, 121, "Bone Microenvironment")]}),

    ("The surface topography of biomaterials can be tailored to enhance cell adhesion and promote tissue regeneration for bone repair.",
     {"entities": [(4, 23, "Surface Topography"), (27, 39, "Biomaterials"), (59, 71, "Cell Adhesion"), (76, 96, "Tissue Regeneration"), (101, 111, "Bone Repair")]}),

    ("Nanoparticles loaded with growth factors exhibit sustained release kinetics, providing prolonged stimulation for bone healing and regeneration.",
     {"entities": [(0, 13, "Nanoparticles"), (23, 36, "Loaded with Growth Factors"), (52, 73, "Sustained Release Kinetics"), (82, 96, "Prolonged Stimulation"), (101, 117, "Bone Healing and Regeneration")]}),

    ("The structural integrity of bone is maintained by a dynamic balance between bone formation and resorption processes.",
     {"entities": [(4, 23, "Structural Integrity"), (27, 31, "Bone"), (48, 54, "Dynamic"), (55, 62, "Balance"), (77, 94, "Bone Formation"), (99, 110, "Resorption Processes")]}),


]

# %%
# Add the new label to ner
ner.add_label(LABEL)

# Resume training
optimizer = nlp.resume_training()
move_names = list(ner.move_names)

# List of pipes you want to train
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]

# List of pipes which should remain unaffected in training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
import random
from spacy.training.example import Example

# TRAINING THE MODEL
# No unaffected_pipes defined
# If you don't have any specific pipeline components to keep unaffected, remove the with statement
# with nlp.disable_pipes(*unaffected_pipes):

# Training for 30 iterations
for iteration in range(30):
    # shuffling examples before every iteration
    random.shuffle(TRAIN_DATA)
    losses = {}

    # batch up the examples using spaCy's minibatch
    batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        examples = []
        for text, annotation in batch:
            example = Example.from_dict(nlp.make_doc(text), annotation)
            examples.append(example)
        nlp.update(examples, drop=0.5, losses=losses)
        print("Losses", losses)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Nanofibrous scaffolds provide a biomimetic environ..." with entities "[(0, 16, 'Nanofibrous Scaffolds'), (36, 51, 'Biomi...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hydroxyapatite-coated implants enhance osseointegr..." with entities "[(0, 14, 'Hydroxyapatite-coated Implants'), (31, 4...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...

# %%
from spacy import displacy

test_text = "The nanostructure of bone tissue plays a crucial role in determining its mechanical strength and flexibility. Hydroxyapatite, a mineral component of bone, contributes to its hardness and rigidity. Osteoblasts, specialized bone cells, produce collagen-rich matrix for bone formation"
doc = nlp(test_text)
print("Entities in '%s'" % test_text)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# Entities in 'The nanostructure of bone tissue plays a crucial role in determining its mechanical strength and flexibility. Hydroxyapatite, a mineral component of bone, contributes to its hardness and rigidity. Osteoblasts, specialized bone cells, produce collagen-rich matrix for bone formation'
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nanostructure
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Architecture</span>
# </mark>
#  of bone tissue plays a crucial role in determining its mechanical strength and flexibility.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hydroxyapatite
# ...
